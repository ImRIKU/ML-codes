# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

fruits = pd.read_table('fruit_data_with_colors.txt')

lookup_fruit_name = dict(zip(fruits.fruit_label.unique(), fruits.fruit_name.unique()))
lookup_fruit_name

X = fruits[['mass', 'width', 'height']]
y = fruits['fruit_label']
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state = 0)

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5)

knn.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 import pandas as pd
#       5 from sklearn.model_selection import train_test_split
# ----> 7 fruits = pd.read_table('fruit_data_with_colors.txt')
#       9 lookup_fruit_name = dict(zip(fruits.fruit_label.unique(), fruits.fruit_name.unique()))
#      10 lookup_fruit_name
#
# ...

# %%
knn.score(x_test, y_test)
type(fruits)
# Out:
# pandas.core.frame.DataFrame

# %%
def plot_fruit_knn(X, y, n_neighbors, weights):
    X_mat = X[['height', 'width']].as_matrix()
    y_mat = y.as_matrix()

    # Create color maps
    cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF','#AFAFAF'])
    cmap_bold  = ListedColormap(['#FF0000', '#00FF00', '#0000FF','#AFAFAF'])

    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X_mat, y_mat)

    # Plot the decision boundary by assigning a color in the color map
    # to each mesh point.
    
    mesh_step_size = .01  # step size in the mesh
    plot_symbol_size = 50
    
    x_min, x_max = X_mat[:, 0].min() - 1, X_mat[:, 0].max() + 1
    y_min, y_max = X_mat[:, 1].min() - 1, X_mat[:, 1].max() + 1
    xx, yy = numpy.meshgrid(numpy.arange(x_min, x_max, mesh_step_size),
                         numpy.arange(y_min, y_max, mesh_step_size))
    Z = clf.predict(numpy.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot training points
    plt.scatter(X_mat[:, 0], X_mat[:, 1], s=plot_symbol_size, c=y, cmap=cmap_bold, edgecolor = 'black')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

    patch0 = mpatches.Patch(color='#FF0000', label='apple')
    patch1 = mpatches.Patch(color='#00FF00', label='mandarin')
    patch2 = mpatches.Patch(color='#0000FF', label='orange')
    patch3 = mpatches.Patch(color='#AFAFAF', label='lemon')
    plt.legend(handles=[patch0, patch1, patch2, patch3])

        
    plt.xlabel('height (cm)')
    plt.ylabel('width (cm)')
    
    plt.show()

# %%
from adspy_shared_utilities import plot_fruit_knn
plot_fruit_knn(x_train, y_train, 5, 'uniform')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6600\913058053.py in ?()
# ----> 2 from adspy_shared_utilities import plot_fruit_knn
#       3 plot_fruit_knn(x_train, y_train, 5, 'uniform')
#
# E:\Macnine Learning Models\adspy_shared_utilities.py in ?(X, y, n_neighbors, weights)
#     172 def plot_fruit_knn(X, y, n_neighbors, weights):
# --> 173     X_mat = X[['height', 'width']].as_matrix()          # changed as_matrix() to values()
#     174     y_mat = y.as_matrix()                                       # same here
#     175
#     176     # Create color maps
#
# c:\users\trex3\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors  # Add this import

def plot_fruit_knn(X, y, n_neighbors, weights):
    X_mat = X[['height', 'width']].values
    y_mat = y.values

    # Create color maps for the plot
    cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF', '#AFAFAF'])  # Light colors for the decision regions
    cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF', '#AFAFAF'])   # Bold colors for the data points

    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X_mat, y_mat)

    # Create a mesh grid to cover the entire feature space
    mesh_step_size = .01  # step size in the mesh
    x_min, x_max = X_mat[:, 0].min() - 1, X_mat[:, 0].max() + 1
    y_min, y_max = X_mat[:, 1].min() - 1, X_mat[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, mesh_step_size),
                         np.arange(y_min, y_max, mesh_step_size))

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Rest of the code remains the same...
    # ... (omitting the unchanged lines for brevity)

    plt.xlabel('height (cm)')
    plt.ylabel('width (cm)')
    
    plt.show()

# %%
plot_fruit_knn(x_train, y_train, 5, 'uniform')
# Out:
# <div id='84e80288-6f9a-486a-88bd-5e94b6fed07b'></div>

# %%
pip install --upgrade ipython matplotlib scikit-learn
# Out:
# Requirement already up-to-date: ipython in c:\users\trex3\appdata\local\programs\python\python38\lib\site-packages (8.12.2)
# Requirement already up-to-date: matplotlib in c:\users\trex3\appdata\local\programs\python\python38\lib\site-packages (3.7.2)
# Requirement already up-to-date: scikit-learn in c:\users\trex3\appdata\local\programs\python\python38\lib\site-packages (1.3.0)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.2.3, however version 23.2.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
fruit_prediction = knn.predict([[20, 4.3, 5.5]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fruit_prediction = knn.predict([[20, 4.3, 5.5]])
#
# NameError: name 'knn' is not defined

# %%
cd ..
cd database
# Out:
#   Cell In[3], line 1
#     cd ..
#         ^
# SyntaxError: invalid syntax

# %%
cd .
